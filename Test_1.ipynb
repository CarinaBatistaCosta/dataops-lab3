# %% [markdown]
# <a href="https://colab.research.google.com/github/CarinaBatistaCosta/dataops-lab3/blob/main/Test_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
uyyhn             import pandas as pd
import openpyxl
import zipfile
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open('/content/BASE_ATUALIZADA_(330_333).xlsx', 'r',encoding='iso-8859-1' ) as file:
    conteudo = file.read()

# %%
dados = pd.read_excel('/content/BASE_ATUALIZADA_(330_333).xlsx')

# %%
dados.head()
# Out:
#                Categoria                 Subcategoria Item-Loja-Semana  \
# 0  38 - LINHAS ESPECIAIS              23 - LALALOOPSY    2820-1008-330
# 1  38 - LINHAS ESPECIAIS              23 - LALALOOPSY    2801-1008-330
# 2         32 - DECORACAO                    46 - BAUS   09184-1004-330
# 3              02 - BABY  09 - MORDEDORES E CHOCALHOS    0943-1008-330
# 4              02 - BABY  09 - MORDEDORES E CHOCALHOS    0943-1010-330
#
#   Cod.Des Material                Desc.Material  Custo Item  Centro  \
# 0             2820     CK - CHAVEIRO LALALOOPSY        4.97    1008
# 1             2801  BON LALALOOPSY MINI SERIE V        9.26    1008
# 2            09184  MORDEDOR CHOCALHO MAMADEIRA       20.08    1004
# 3             0943  MORDEDOR CHOCALHO MAMADEIRA       20.08    1008
# 4             0943  MORDEDOR CHOCALHO MAMADEIRA       20.08    1010
#
#                Desc.Centro      Loja  Entr. Pedido Qtd.  ...  \
# 0  RI HAPPY BRINQUEDOS S.A  RI HAPPY                NaN  ...
# ...

# %%
dados.columns
# Out:
# Index(['Categoria', 'Subcategoria', 'Item-Loja-Semana', 'Cod.Des Material',
#        'Desc.Material', 'Custo Item', 'Centro', 'Desc.Centro', 'Loja',
#        'Entr. Pedido Qtd.', 'Entr. Pedido Valor', 'Valor Est. Inicial',
#        'Est. Início Qtd.', 'Est.Qtd.', 'Est.Custo', 'Venda Qtd.', 'Venda PV',
#        'Venda Custo', 'Pedido Pend. Qtde.', 'Data', 'Semana',
#        'Estoque Inicial Qtd.', 'Estoque Inicial Valor', 'Estoque Custo',
#        'Estoque Qtd.', 'Venda Quantidade', 'Valor Venda Custo', 'Pedido Valor',
#        'Pedido Qtd.', 'Data Fim', 'Data Início', 'Item Ativo', 'Cidade',
#        'Estado', 'Bairro'],
#       dtype='object')

# %%
##arquivo zipado
dados
# Out:
#                    Categoria                 Subcategoria Item-Loja-Semana  \
# 0      38 - LINHAS ESPECIAIS              23 - LALALOOPSY    2820-1008-330
# 1      38 - LINHAS ESPECIAIS              23 - LALALOOPSY    2801-1008-330
# 2             32 - DECORACAO                    46 - BAUS   09184-1004-330
# 3                  02 - BABY  09 - MORDEDORES E CHOCALHOS    0943-1008-330
# 4                  02 - BABY  09 - MORDEDORES E CHOCALHOS    0943-1010-330
# ...                      ...                          ...              ...
# 65181            ALIMENTACAO                       PRATOS   15323-1300-333
# 65182            ALIMENTACAO                       PRATOS   15324-1300-333
# 65183                   SONO                     NANINHAS   15365-1304-333
# 65184            ALIMENTACAO                    BABADORES   15342-1304-333
# 65185            ALIMENTACAO                    BABADORES   15342-1305-333
#
# ...

# %%
dados.columns
# Out:
# Index(['Categoria', 'Subcategoria', 'Item-Loja-Semana', 'Cod.Des Material',
#        'Desc.Material', 'Custo Item', 'Centro', 'Desc.Centro', 'Loja',
#        'Entr. Pedido Qtd.', 'Entr. Pedido Valor', 'Valor Est. Inicial',
#        'Est. Início Qtd.', 'Est.Qtd.', 'Est.Custo', 'Venda Qtd.', 'Venda PV',
#        'Venda Custo', 'Pedido Pend. Qtde.', 'Data', 'Semana',
#        'Estoque Inicial Qtd.', 'Estoque Inicial Valor', 'Estoque Custo',
#        'Estoque Qtd.', 'Venda Quantidade', 'Valor Venda Custo', 'Pedido Valor',
#        'Pedido Qtd.', 'Data Fim', 'Data Início', 'Item Ativo', 'Cidade',
#        'Estado', 'Bairro'],
#       dtype='object')

# %%
dados['Custo Item'].max()
# Out:
# 156.03

# %%
dados.describe()
# Out:
#          Custo Item        Centro  Entr. Pedido Qtd.  Entr. Pedido Valor  \
# count  65186.000000  65186.000000                0.0                 0.0
# mean      22.941216   3252.851809                NaN                 NaN
# std       19.754811   3501.606796                NaN                 NaN
# min        0.210000   1002.000000                NaN                 NaN
# 25%       10.740000   1075.000000                NaN                 NaN
# 50%       17.630000   1169.000000                NaN                 NaN
# 75%       26.850000   9006.000000                NaN                 NaN
# max      156.030000   9090.000000                NaN                 NaN
#
#        Valor Est. Inicial  Est. Início Qtd.      Est.Qtd.     Est.Custo  \
# count                 0.0               0.0  65186.000000  65186.000000
# mean                  NaN               NaN      4.860215     98.044372
# std                   NaN               NaN      5.151929    120.061661
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65186 entries, 0 to 65185
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Categoria              65170 non-null  object
#  1   Subcategoria           65170 non-null  object
#  2   Item-Loja-Semana       65170 non-null  object
#  3   Cod.Des Material       65170 non-null  object
#  4   Desc.Material          65185 non-null  object
#  5   Custo Item             65186 non-null  float64
#  6   Centro                 65186 non-null  int64
#  7   Desc.Centro            65186 non-null  object
#  8   Loja                   65186 non-null  object
#  9   Entr. Pedido Qtd.      0 non-null      float64
#  10  Entr. Pedido Valor     0 non-null      float64
#  11  Valor Est. Inicial     0 non-null      float64
#  12  Est. Início Qtd.       0 non-null      float64
#  13  Est.Qtd.               65186 non-null  int64
# ...

# %%
# Out:
# <ipython-input-55-9a69b4cd6735>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.agg("mean", axis="columns")
#                    Categoria                 Subcategoria Item-Loja-Semana  \
# 0      38 - LINHAS ESPECIAIS              23 - LALALOOPSY    2820-1008-330
# 1      38 - LINHAS ESPECIAIS              23 - LALALOOPSY    2801-1008-330
# 2             32 - DECORACAO                    46 - BAUS   09184-1004-330
# 3                  02 - BABY  09 - MORDEDORES E CHOCALHOS    0943-1008-330
# 4                  02 - BABY  09 - MORDEDORES E CHOCALHOS    0943-1010-330
# ...                      ...                          ...              ...
# 65181            ALIMENTACAO                       PRATOS   15323-1300-333
# ...

# %%
dados_categoria = dados.groupby(['Categoria'])['Est.Qtd.'].agg(['count','max'])
dados_categoria
# Out:
#                        count  max
# Categoria
# 01 - PLUSH               460   46
# 02 - BABY               6928   43
# 03 - DOLLS               181   26
# 04 - FUN E PILLOW          4    4
# 08 - MARVEL               16   10
# 09 - DISNEY                4    7
# 10 - LALALOOPSY           24    9
# 11 - PRAIA E PISCINA      32    8
# 13 - CABANA                3    4
# 31 - ILUMINACAO            2    3
# 32 - DECORACAO            56   20
# 38 - LINHAS ESPECIAIS     81   14
# 39 - LICENCAS            120   26
# 40 - MAMAES                4    8
# 41 - ALIMENTACAO       23448   72
# 42 - BANHO              1678   30
# 43 - BRINQUEDO         18255  104
# 44 - CUIDADOS           3283   34
# 45 - PASSEIO            1769   84
# 46 - SONO               1489   51
# ALIMENTACAO             4428   50
# BRINQUEDO               1775   34
# CUIDADOS                   4    2
# PASSEIO                  173   13
# SONO                     953   17

# %%
fig, ax = plt.subplots(figsize=(50, 30))
sns.barplot(data=dados, x="Categoria", y="Est.Qtd.")
# Out:
# <Axes: xlabel='Categoria', ylabel='Est.Qtd.'>

# %%
fig, ax = plt.subplots(figsize=(20, 20))

sns.countplot(data=dados, y="Categoria")
# Out:
# <Axes: xlabel='count', ylabel='Categoria'>

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
may_flights = dados.query(" Categoria == 'ALIMENTACAO'")
sns.lineplot(data=may_flights, x="Categoria", y="Est.Qtd.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2cadc1ba6c1f> in <cell line: 1>()
# ----> 1 may_flights = dados.query(" Categoria == 'ALIMENTACAO'")
#       2 sns.lineplot(data=may_flights, x="Categoria", y="Est.Qtd.")
#
# NameError: name 'dados' is not defined
